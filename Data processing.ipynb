# %%
import numpy as np

# %%
import pandas as pd

# %%
file=pd.read_csv('job_descriptions.csv')

# %%
file.head()
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
file['Experience']
# Out:
# 0          5 to 15 Years
# 1          2 to 12 Years
# 2          0 to 12 Years
# 3          4 to 11 Years
# 4          1 to 12 Years
#                ...
# 1615935    0 to 12 Years
# 1615936    2 to 14 Years
# 1615937    4 to 15 Years
# 1615938    5 to 15 Years
# 1615939    1 to 11 Years
# Name: Experience, Length: 1615940, dtype: object

# %%
t=file['Experience'].str.split()

# %%
t
# Out:
# 0          [5, to, 15, Years]
# 1          [2, to, 12, Years]
# 2          [0, to, 12, Years]
# 3          [4, to, 11, Years]
# 4          [1, to, 12, Years]
#                   ...
# 1615935    [0, to, 12, Years]
# 1615936    [2, to, 14, Years]
# 1615937    [4, to, 15, Years]
# 1615938    [5, to, 15, Years]
# 1615939    [1, to, 11, Years]
# Name: Experience, Length: 1615940, dtype: object

# %%
acc=[]
for i in t:
    acc.append(i[0])

# %%
bcc=[]
for i in t:
    bcc.append(i[2])

# %%
acc
# Out:
# ['5',
#  '2',
#  '0',
#  '4',
#  '1',
#  '4',
#  '3',
#  '2',
#  '2',
#  '1',
#  '3',
#  '4',
#  '3',
#  '1',
#  '1',
#  '4',
#  '5',
#  '0',
#  '3',
#  '5',
#  '0',
#  '0',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '4',
#  '0',
#  '2',
#  '4',
#  '3',
#  '1',
#  '1',
#  '0',
#  '3',
#  '0',
#  '0',
#  '4',
#  '5',
#  '5',
#  '2',
#  '4',
#  '0',
#  '1',
#  '1',
#  '3',
#  '5',
#  '3',
#  '4',
#  '5',
#  '4',
#  '4',
#  '5',
#  '0',
#  '5',
#  '4',
#  '4',
#  '2',
#  '2',
#  '3',
#  '5',
#  '0',
#  '1',
#  '4',
#  '0',
#  '4',
#  '3',
#  '1',
#  '0',
#  '3',
#  '5',
#  '5',
#  '2',
#  '1',
#  '1',
#  '1',
#  '4',
#  '4',
#  '2',
#  '4',
#  '1',
#  '4',
#  '4',
#  '1',
#  '5',
#  '0',
#  '0',
#  '5',
#  '2',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '1',
#  '1',
#  '4',
#  '4',
#  '1',
#  '5',
#  '4',
#  '0',
#  '0',
#  '0',
#  '1',
#  '5',
#  '4',
#  '1',
#  '0',
#  '3',
#  '4',
#  '5',
#  '5',
#  '4',
#  '2',
#  '3',
#  '3',
#  '0',
#  '4',
#  '2',
#  '2',
#  '2',
#  '5',
#  '4',
# ...

# %%
file['upperbexperience']=bcc

# %%
file['lowerbexperience']=acc

# %%
file.to_csv('jobdata2.csv')

# %%
rf=pd.read_csv('jobdata2.csv')

# %%
rf
# Out:
#          Unnamed: 0            Job Id     Experience Qualifications  \
# 0                 0  1089843540111562  5 to 15 Years         M.Tech
# 1                 1   398454096642776  2 to 12 Years            BCA
# 2                 2   481640072963533  0 to 12 Years            PhD
# 3                 3   688192671473044  4 to 11 Years            PhD
# 4                 4   117057806156508  1 to 12 Years            MBA
# ...             ...               ...            ...            ...
# 1615935     1615935   134563577088850  0 to 12 Years         B.Tech
# 1615936     1615936   618604818190827  2 to 14 Years         M.Tech
# 1615937     1615937   615471367712200  4 to 15 Years            BCA
# 1615938     1615938   804137342023945  5 to 15 Years            BCA
# 1615939     1615939   404645755314484  1 to 11 Years            BBA
#
#         Salary Range           location            Country  latitude  \
# 0          $59K-$99K            Douglas        Isle of Man   54.2361
# ...

# %%
rf['Country']
# Out:
# 0                Isle of Man
# 1               Turkmenistan
# 2           Macao SAR, China
# 3                      Benin
# 4                      Chile
#                  ...
# 1615935    Equatorial Guinea
# 1615936               Poland
# 1615937         Turkmenistan
# 1615938         Burkina Faso
# 1615939              Eritrea
# Name: Country, Length: 1615940, dtype: object

# %%
rf['Salary Range']
# Out:
# 0           $59K-$99K
# 1          $56K-$116K
# 2          $61K-$104K
# 3           $65K-$91K
# 4           $64K-$87K
#               ...
# 1615935    $64K-$114K
# 1615936    $62K-$130K
# 1615937     $60K-$96K
# 1615938    $65K-$103K
# 1615939    $56K-$109K
# Name: Salary Range, Length: 1615940, dtype: object

# %%
t=file['Salary Range'].str.split('-')
tg=[]
for i in t:
    tg.append(i[0])
for i in range(len(tg)):
    tg[i]=int(tg[i][1:-1])
tg
# Out:
# [59,
#  56,
#  61,
#  65,
#  64,
#  59,
#  63,
#  65,
#  65,
#  60,
#  57,
#  64,
#  65,
#  56,
#  57,
#  65,
#  60,
#  55,
#  55,
#  65,
#  62,
#  64,
#  58,
#  62,
#  60,
#  58,
#  59,
#  64,
#  63,
#  65,
#  55,
#  65,
#  57,
#  65,
#  62,
#  58,
#  60,
#  64,
#  57,
#  58,
#  56,
#  55,
#  62,
#  65,
#  56,
#  59,
#  56,
#  64,
#  59,
#  57,
#  62,
#  55,
#  59,
#  59,
#  64,
#  60,
#  63,
#  57,
#  65,
#  65,
#  61,
#  57,
#  56,
#  65,
#  65,
#  55,
#  59,
#  63,
#  64,
#  56,
#  64,
#  58,
#  56,
#  65,
#  64,
#  60,
#  55,
#  56,
#  63,
#  55,
#  61,
#  56,
#  65,
#  57,
#  63,
#  59,
#  65,
#  56,
#  55,
#  61,
#  58,
#  60,
#  57,
#  64,
#  58,
#  61,
#  55,
#  58,
#  58,
#  59,
#  63,
#  55,
#  62,
#  61,
#  64,
#  59,
#  64,
#  61,
#  62,
#  64,
#  59,
#  56,
#  60,
#  60,
#  61,
#  65,
#  65,
#  65,
#  63,
#  64,
#  63,
#  55,
#  63,
#  56,
#  60,
#  60,
#  60,
#  55,
#  62,
#  58,
#  55,
#  59,
#  65,
#  57,
#  65,
#  57,
#  56,
#  62,
#  56,
#  56,
#  61,
#  60,
# ...

# %%
ok=min(tg)

# %%
ok
# Out:
# 55

# %%
rf['lowerbsalary']=tg

# %%
rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615940 entries, 0 to 1615939
# Data columns (total 27 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1615940 non-null  int64
#  1   Job Id            1615940 non-null  int64
#  2   Experience        1615940 non-null  object
#  3   Qualifications    1615940 non-null  object
#  4   Salary Range      1615940 non-null  object
#  5   location          1615940 non-null  object
#  6   Country           1615940 non-null  object
#  7   latitude          1615940 non-null  float64
#  8   longitude         1615940 non-null  float64
#  9   Work Type         1615940 non-null  object
#  10  Company Size      1615940 non-null  int64
#  11  Job Posting Date  1615940 non-null  object
#  12  Preference        1615940 non-null  object
#  13  Contact Person    1615940 non-null  object
#  14  Contact           1615940 non-null  object
# ...

# %%
african_countries = [
    'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde',
    'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo', 'Congo, Democratic Republic of the',
    'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana',
    'Guinea', 'Guinea-Bissau', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi',
    'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
    'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan',
    'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe', 'Sahrawi Arab Democratic Republic'
]
# len(african_countries)
asian_countries = [
    "Afghanistan", "Armenia", "Azerbaijan", "Bahrain", "Bangladesh", "Bhutan", "Brunei",
    "Cambodia", "China", "Cyprus", "Georgia", "India", "Indonesia", "Iran", "Iraq",
    "Israel", "Japan", "Jordan", "Kazakhstan", "Kuwait", "Kyrgyzstan", "Laos", "Lebanon",
    "Malaysia", "Maldives", "Mongolia", "Myanmar", "Nepal", "North Korea", "Oman",
    "Pakistan", "Palestine", "Philippines", "Qatar", "Russia", "Saudi Arabia", "Singapore",
    "South Korea", "Sri Lanka", "Syria", "Taiwan", "Tajikistan", "Thailand", "Timor-Leste",
    "Turkey", "Turkmenistan", "United Arab Emirates", "Uzbekistan", "Vietnam", "Yemen"
]

# %%
def is_african_country(country):
    return country in african_countries

# %%
def is_asian_country(country):
    return country in african_countries

# %%
rf['is_african'] = rf['Country'].apply(is_african_country)

# %%
rf['is_asian'] = rf['Country'].apply(is_asian_country)

# %%
rf['is_african']
# Out:
# 0          False
# 1          False
# 2          False
# 3           True
# 4          False
#            ...
# 1615935     True
# 1615936    False
# 1615937    False
# 1615938     True
# 1615939     True
# Name: is_african, Length: 1615940, dtype: bool

# %%
acc=[]
for i in rf['Job Title']:
    if i[0]=='D':
        acc.append(True)
    else:
        acc.append(False)

# %%
rf['JobwithD']=acc

# %%
rf
# Out:
#          Unnamed: 0            Job Id     Experience Qualifications  \
# 0                 0  1089843540111562  5 to 15 Years         M.Tech
# 1                 1   398454096642776  2 to 12 Years            BCA
# 2                 2   481640072963533  0 to 12 Years            PhD
# 3                 3   688192671473044  4 to 11 Years            PhD
# 4                 4   117057806156508  1 to 12 Years            MBA
# ...             ...               ...            ...            ...
# 1615935     1615935   134563577088850  0 to 12 Years         B.Tech
# 1615936     1615936   618604818190827  2 to 14 Years         M.Tech
# 1615937     1615937   615471367712200  4 to 15 Years            BCA
# 1615938     1615938   804137342023945  5 to 15 Years            BCA
# 1615939     1615939   404645755314484  1 to 11 Years            BBA
#
#         Salary Range           location            Country  latitude  \
# 0          $59K-$99K            Douglas        Isle of Man   54.2361
# ...

# %%
acc=[]
for i in rf['Contact Person']:
    if i[0]=='D':
        acc.append(True)
    else:
        acc.append(False)

# %%
rf['contactA']=acc

# %%
rf
# Out:
#          Unnamed: 0            Job Id     Experience Qualifications  \
# 0                 0  1089843540111562  5 to 15 Years         M.Tech
# 1                 1   398454096642776  2 to 12 Years            BCA
# 2                 2   481640072963533  0 to 12 Years            PhD
# 3                 3   688192671473044  4 to 11 Years            PhD
# 4                 4   117057806156508  1 to 12 Years            MBA
# ...             ...               ...            ...            ...
# 1615935     1615935   134563577088850  0 to 12 Years         B.Tech
# 1615936     1615936   618604818190827  2 to 14 Years         M.Tech
# 1615937     1615937   615471367712200  4 to 15 Years            BCA
# 1615938     1615938   804137342023945  5 to 15 Years            BCA
# 1615939     1615939   404645755314484  1 to 11 Years            BBA
#
#         Salary Range           location            Country  latitude  \
# 0          $59K-$99K            Douglas        Isle of Man   54.2361
# ...

# %%
# acc

# %%
t=file['Salary Range'].str.split('-')
tg=[]
for i in t:
    # print(i)
    tg.append(i[1])
# print(t)
# print(tg)
for i in range(len(tg)):
    tg[i]=int(tg[i][1:-1])
# tg

# %%
tg
# Out:
# [99,
#  116,
#  104,
#  91,
#  87,
#  93,
#  103,
#  102,
#  102,
#  80,
#  104,
#  98,
#  122,
#  86,
#  98,
#  100,
#  83,
#  117,
#  121,
#  128,
#  120,
#  98,
#  116,
#  124,
#  104,
#  107,
#  88,
#  100,
#  86,
#  119,
#  83,
#  115,
#  121,
#  82,
#  130,
#  129,
#  89,
#  103,
#  100,
#  81,
#  109,
#  121,
#  129,
#  95,
#  82,
#  80,
#  109,
#  130,
#  89,
#  97,
#  127,
#  105,
#  123,
#  114,
#  92,
#  102,
#  109,
#  125,
#  88,
#  117,
#  111,
#  125,
#  94,
#  121,
#  84,
#  96,
#  101,
#  114,
#  82,
#  125,
#  83,
#  88,
#  128,
#  88,
#  82,
#  113,
#  87,
#  101,
#  102,
#  121,
#  105,
#  93,
#  96,
#  83,
#  104,
#  113,
#  107,
#  91,
#  128,
#  82,
#  115,
#  113,
#  83,
#  103,
#  83,
#  106,
#  126,
#  121,
#  81,
#  108,
#  85,
#  118,
#  129,
#  94,
#  113,
#  105,
#  86,
#  116,
#  94,
#  89,
#  94,
#  95,
#  95,
#  112,
#  122,
#  107,
#  83,
#  113,
#  96,
#  124,
#  130,
#  127,
#  113,
#  129,
#  107,
#  100,
#  124,
#  88,
#  102,
#  125,
#  111,
# ...

# %%
rf['upperbsalary']=tg

# %%
rf['salaryrange']=rf['upperbsalary']-rf['lowerbsalary']

# %%
rf
# Out:
#          Unnamed: 0            Job Id     Experience Qualifications  \
# 0                 0  1089843540111562  5 to 15 Years         M.Tech
# 1                 1   398454096642776  2 to 12 Years            BCA
# 2                 2   481640072963533  0 to 12 Years            PhD
# 3                 3   688192671473044  4 to 11 Years            PhD
# 4                 4   117057806156508  1 to 12 Years            MBA
# ...             ...               ...            ...            ...
# 1615935     1615935   134563577088850  0 to 12 Years         B.Tech
# 1615936     1615936   618604818190827  2 to 14 Years         M.Tech
# 1615937     1615937   615471367712200  4 to 15 Years            BCA
# 1615938     1615938   804137342023945  5 to 15 Years            BCA
# 1615939     1615939   404645755314484  1 to 11 Years            BBA
#
#         Salary Range           location            Country  latitude  \
# 0          $59K-$99K            Douglas        Isle of Man   54.2361
# ...

# %%
max(rf['salaryrange'])
# Out:
# 75

# %%
rf.to_csv('jobdata2.csv')

# %%
rf=pd.read_csv('jobdata2.csv')
rf
# Out:
#          Unnamed: 0.1  Unnamed: 0            Job Id     Experience  \
# 0                   0           0  1089843540111562  5 to 15 Years
# 1                   1           1   398454096642776  2 to 12 Years
# 2                   2           2   481640072963533  0 to 12 Years
# 3                   3           3   688192671473044  4 to 11 Years
# 4                   4           4   117057806156508  1 to 12 Years
# ...               ...         ...               ...            ...
# 1615935       1615935     1615935   134563577088850  0 to 12 Years
# 1615936       1615936     1615936   618604818190827  2 to 14 Years
# 1615937       1615937     1615937   615471367712200  4 to 15 Years
# 1615938       1615938     1615938   804137342023945  5 to 15 Years
# 1615939       1615939     1615939   404645755314484  1 to 11 Years
#
#         Qualifications Salary Range           location            Country  \
# 0               M.Tech    $59K-$99K            Douglas        Isle of Man
# ...
